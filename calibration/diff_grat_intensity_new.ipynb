# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### 450nm

# %% [markdown]
# #### m = 0 order

# %%
nm450 = cv2.imread('./diff_efficiency/450nm.png')[160:190, 760:790]
nm450 = cv2.cvtColor(nm450, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm450)

# %%
nm450_reshape = nm450.reshape(-1,3)

# %%
nm450_mean = nm450_reshape.mean(axis = 0)

# %%
nm450_mean
# Out:
# array([ 21.56888889,  30.26      , 229.63888889])

# %% [markdown]
# #### m = 1 order

# %%
nm450_1 = cv2.imread('./diff_efficiency/450nm.png')[160:190, 390:420]
nm450_1 = cv2.cvtColor(nm450_1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm450_1)

# %%
nm450_1_reshape = nm450_1.reshape(-1,3)

# %%
nm450_1_mean = nm450_1_reshape.mean(axis = 0)

# %%
nm450_1_mean
# Out:
# array([16.10333333, 17.89555556, 54.81777778])

# %% [markdown]
# ### 500nm

# %% [markdown]
# #### m = 0 order

# %%
nm500 = cv2.imread('./diff_efficiency/500nm.png')[160:190, 760:790]
nm500 = cv2.cvtColor(nm500, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm500)

# %%
nm500_reshape = nm500.reshape(-1,3)

# %%
nm500_mean = nm500_reshape.mean(axis = 0)

# %%
nm500_mean
# Out:
# array([16.84666667, 75.87777778, 50.27222222])

# %% [markdown]
# ### m = 1 order

# %%
nm500_1 = cv2.imread('./diff_efficiency/500nm.png')[160:190, 350:380]
nm500_1 = cv2.cvtColor(nm500_1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm500_1)

# %%
nm500_1_reshape = nm500_1.reshape(-1,3)

# %%
nm500_1_mean = nm500_1_reshape.mean(axis = 0)

# %%
nm500_1_mean
# Out:
# array([15.23222222, 25.25333333, 20.66444444])

# %% [markdown]
# ### 550nm

# %% [markdown]
# #### m = 0

# %%
nm550 = cv2.imread('./diff_efficiency/550nm.png')[160:190, 760:790]
nm550 = cv2.cvtColor(nm550, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm550)

# %%
nm550_reshape = nm550.reshape(-1,3)

# %%
nm550_mean = nm550_reshape.mean(axis = 0)

# %%
nm550_mean
# Out:
# array([ 21.01333333, 166.86777778,  29.44111111])

# %% [markdown]
# #### m = 1 order

# %%
nm550_1 = cv2.imread('./diff_efficiency/550nm.png')[160:190, 310:340]
nm550_1 = cv2.cvtColor(nm550_1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm550_1)

# %%
nm550_1_reshape = nm550_1.reshape(-1,3)

# %%
nm550_1_mean = nm550_1_reshape.mean(axis = 0)

# %%
nm550_1_mean
# Out:
# array([15.77444444, 31.95444444, 16.59555556])

# %% [markdown]
# ### 600nm

# %% [markdown]
# #### m = 0 order

# %%
nm600 = cv2.imread('./diff_efficiency/600nm.png')[160:190, 760:790]
nm600 = cv2.cvtColor(nm600, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm600)

# %%
nm600_reshape = nm600.reshape(-1,3)

# %%
nm600_mean = nm600_reshape.mean(axis = 0)

# %%
nm600_mean
# Out:
# array([62.78666667, 45.57777778, 16.18222222])

# %% [markdown]
# #### m = 1 order

# %%
nm600_1 = cv2.imread('./diff_efficiency/600nm.png')[160:190, 270:300]
nm600_1 = cv2.cvtColor(nm600_1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm600_1)

# %%
nm600_1_reshape = nm600_1.reshape(-1,3)

# %%
nm600_1_mean = nm600_1_reshape.mean(axis = 0)

# %%
nm600_1_mean
# Out:
# array([20.01444444, 18.39111111, 15.06555556])

# %% [markdown]
# ### 650nm
# #### m = 0 order

# %%
nm650 = cv2.imread('./diff_efficiency/650nm.png')[160:190, 760:790]
nm650 = cv2.cvtColor(nm650, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm650)

# %%
nm650_reshape = nm650.reshape(-1,3)

# %%
nm650_mean = nm650_reshape.mean(axis = 0)

# %%
nm650_mean
# Out:
# array([198.34666667,  52.40888889,  22.20666667])

# %% [markdown]
# #### m = 1 order

# %%
nm650_1 = cv2.imread('./diff_efficiency/650nm.png')[160:190, 230:260]
nm650_1 = cv2.cvtColor(nm650_1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nm650_1)

# %%
nm650_1_reshape = nm650_1.reshape(-1,3)

# %%
nm650_1_mean = nm650_1_reshape.mean(axis = 0)

# %%
nm650_1_mean
# Out:
# array([28.95333333, 17.99111111, 15.33222222])

# %% [markdown]
# ### Diffraction Efficiency

# %%
nm450_1_mean, nm450_mean
# Out:
# (array([16.10333333, 17.89555556, 54.81777778]),
#  array([ 21.56888889,  30.26      , 229.63888889]))

# %%
nm450_1_mean/nm450_mean
# Out:
# array([0.74660004, 0.59139311, 0.23871296])

# %%
nm500_1_mean, nm500_mean
# Out:
# (array([15.23222222, 25.25333333, 20.66444444]),
#  array([16.84666667, 75.87777778, 50.27222222]))

# %%
nm500_1_mean/nm500_mean
# Out:
# array([0.90416832, 0.33281593, 0.41105094])

# %%
nm550_1_mean, nm550_mean
# Out:
# (array([15.77444444, 31.95444444, 16.59555556]),
#  array([ 21.01333333, 166.86777778,  29.44111111]))

# %%
nm550_1_mean/nm550_mean
# Out:
# array([0.75068739, 0.1914956 , 0.56368646])

# %%
nm600_1_mean, nm600_mean
# Out:
# (array([20.01444444, 18.39111111, 15.06555556]),
#  array([62.78666667, 45.57777778, 16.18222222]))

# %%
nm600_1_mean/nm600_mean
# Out:
# array([0.31876902, 0.40351048, 0.93099423])

# %%
nm650_1_mean, nm650_mean
# Out:
# (array([28.95333333, 17.99111111, 15.33222222]),
#  array([198.34666667,  52.40888889,  22.20666667]))

# %%
nm650_1_mean/nm650_mean
# Out:
# array([0.14597338, 0.34328358, 0.6904333 ])

# %% [markdown]
# ### Interpolation

# %%
from scipy import interpolate
import torch

# %%
y = torch.tensor([ 0.2,0.23871296,0.33281593,0.1914956,0.31876902,0.14597338, 0.143])

# %%
def cubic_interpolation(x_new, x_points, y_points, n):
    tck = interpolate.splrep(x_points, y_points, k=n)   # Estimate the polynomial of nth degree by using x_points and y_points
    y_new = interpolate.splev(x_new, tck)
    return y_new

# %%
wvls = torch.tensor([420, 450, 500, 550, 600, 650, 660])*1e-9
new_wvls = torch.linspace(420*1e-9, 660*1e-9, 25) # 400 ~ 680 까지 10nm 간격으로

order1 = cubic_interpolation(new_wvls, wvls, y, 4)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5))
plt.subplot(131), plt.plot(new_wvls, order1), plt.title('order m = 1')
# Out:
# (<AxesSubplot:title={'center':'order m = 1'}>,
# ...
#  Text(0.5, 1.0, 'order m = 1'))

# %%
order1
# Out:
# array([0.2       , 0.18133375, 0.20029072, 0.23871297, 0.28195055,
#        0.31886078, 0.34180867, 0.34666699, 0.33281592, 0.30314333,
#        0.26404474, 0.22539884, 0.19871118, 0.1914956 , 0.20541875,
#        0.23627495, 0.27401593, 0.3049963 , 0.31876903, 0.3103309 ,
#        0.28015208, 0.23417634, 0.18381997, 0.14597338, 0.14300014])

# %%
import numpy as np

# %%
intensity_dg = np.zeros(shape=(3,25))

# %%
intensity_dg[1] = 1.

# %%
intensity_dg[0] = order1 * 0.65
intensity_dg[2] = order1 * 0.65

# %%
np.save('./intensity_dg_0502.npy', intensity_dg)
